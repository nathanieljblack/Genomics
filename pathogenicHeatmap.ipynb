# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Get All Possible Mutations
# Using the matrix data, grab all possible mutations

# %%
matrix_df = pd.read_csv('/Users/nathanielblack/Downloads/MatrixGenomDt_Mt_T.csv', sep ='\t', index_col=False)
all_mutations = [mut for mut in matrix_df.columns if mut != 'Mut']

# %% [markdown]
# #Get the IDs We Use in Viz2
# - Load the data used in Viz2
# - Pivot the data so we have a column for each *Sample* with the *Clinical_Significance* as the value

# %%
genomic_df = pd.read_csv('/Users/nathanielblack/Downloads/genomicDtMt.csv')

# %%
all_mutations = pd.DataFrame(all_mutations, columns=['Mut'])

# %%
severity_map = {0:0,1:0,2:0,3:0,4:-1,5:-2}
genomic_df['Severity'] = genomic_df['Clinical_Significance'].map(severity_map)
people_columns = genomic_df.pivot_table(index = 'Mut', columns='Sample', values='Severity')
people_columns = people_columns.reset_index()

# %% [markdown]
# #Combine All Mutations and Viz2 Data
# - Left join the viz2 data to the all mutation data
# - Replace NA with 0
#
# Result will be a matrix of mutation by person with severity as the values

# %%
mut_by_person_df = all_mutations.merge(people_columns, how='left', on='Mut')
mut_by_person_df.fillna(0, inplace=True)
mut_by_person_df.set_index('Mut', inplace=True)

# %% [markdown]
# #Add Population Info
# - create an ID to population map
# - Append the population info to the mutation by person matrix

# %%
population_info = genomic_df[['Sample','Population']].drop_duplicates()
pop_df = mut_by_person_df.T
pop_df['Sample'] = pop_df.index
pop_df = pop_df.merge(population_info, how='left', on='Sample')
pop_df.set_index(['Population','Sample'], inplace=True)

# %% [markdown]
# #Heatmap
# We now have a dataframe that can be used as a heatmap

# %%
#for pop in genomic_df.Population.unique().tolist()[:-1]:
#    print "*"*20 + pop + "*"*20
#    ax = sns.heatmap(pop_df.ix[pop])
#    ax.xaxis.set_visible(False)
#    ax.yaxis.set_visible(False)
#    plt.ylabel('Person')
#    plt.xlabel('Mutation')
#    plt.show();

# %%
pop_df.head()
# Out:
# Mut                 chrMT-827-G  chrMT-951-A  chrMT-961-CG  chrMT-980-C  \
# Population Sample
# GBR        HG00096            0            0             0            0
#            HG00097            0            0             0            0
#            HG00099            0            0             0            0
#            HG00100            0            0             0            0
#            HG00101            0            0             0            0
#
# Mut                 chrMT-990-C  chrMT-1005-C  chrMT-1007-A  chrMT-1008-G  \
# Population Sample
# GBR        HG00096            0             0             0             0
#            HG00097            0             0             0             0
#            HG00099            0             0             0             0
#            HG00100            0             0             0             0
#            HG00101            0             0             0             0
#
# Mut                 chrMT-1018-A  chrMT-1027-G      ...        chrMT-15553-A  \
# Population Sample                                   ...
# GBR        HG00096             0             0      ...                    0
#            HG00097             0             0      ...                    0
#            HG00099             0             0      ...                   -1
#            HG00100             0             0      ...                    0
#            HG00101             0             0      ...                    0
#
# Mut                 chrMT-15607-G  chrMT-15637-T  chrMT-15649-G  \
# Population Sample
# GBR        HG00096              0              0              0
#            HG00097             -1              0              0
#            HG00099              0              0              0
#            HG00100              0              0              0
#            HG00101              0              0              0
#
# Mut                 chrMT-15670-C  chrMT-15682-G  chrMT-15758-G  \
# Population Sample
# GBR        HG00096              0              0              0
#            HG00097              0              0              0
#            HG00099              0              0              0
#            HG00100              0              0              0
#            HG00101              0              0              0
#
# Mut                 chrMT-15784-C  chrMT-15812-A  chrMT-15927-A
# Population Sample
# GBR        HG00096              0              0              0
#            HG00097              0              0              0
#            HG00099              0              0              0
#            HG00100              0              0             -1
#            HG00101              0              0              0
#
# [5 rows x 111 columns]

# %%
pop_df.reset_index(inplace=True)
melt_vars = [col for col in pop_df.columns if col not in ['Population', 'Sample']]
pop_df = pd.melt(pop_df, id_vars=['Population','Sample'], value_vars = melt_vars, value_name = 'Severity')

# %%
out = pop_df.copy(deep=True)
out.sort(['Population'])
out['col'] = pd.Categorical(out.Mut).codes

# %%
out.head()
# Out:
#   Population   Sample          Mut  Severity  col
# 0        GBR  HG00096  chrMT-827-G         0  102
# 1        GBR  HG00097  chrMT-827-G         0  102
# 2        GBR  HG00099  chrMT-827-G         0  102
# 3        GBR  HG00100  chrMT-827-G         0  102
# 4        GBR  HG00101  chrMT-827-G         0  102

# %%
df = out.copy(deep=True)
df.sort('Population', inplace=True)
df['row'] = pd.Categorical(df.Sample).codes
print df.row.max()
df = df[df.Severity != 0]
df.sort(['Population','row','col'], inplace=True)
df.to_csv('/Users/nathanielblack/Dropbox/d3/heatmaps/overall_heatmap.csv', index=False)
# Out:
# 1271

# %%
genomic_df.Population.unique().tolist()[:-1]
# Out:
# ['GBR',
#  'FIN',
#  'CHS',
#  'PUR',
#  'CDX',
#  'CLM',
#  'IBS',
#  'PEL',
#  'PJL',
#  'KHV',
#  'ACB',
#  'GWD',
#  'ESN',
#  'BEB',
#  'MSL']

# %%
genomic_df[genomic_df.Mut == 'chrMT-10398-G']
# Out:
#       Unnamed: 0 CHROM_x  POS_x REF_x ALT_x        INFO_x   Sample  value  \
# 20            20      MT  10398     A     G  VT=S;AC=1397  HG00101      1
# 27            27      MT  10398     A     G  VT=S;AC=1397  HG00103      1
# 35            35      MT  10398     A     G  VT=S;AC=1397  HG00106      1
# 44            44      MT  10398     A     G  VT=S;AC=1397  HG00107      1
# 79            79      MT  10398     A     G  VT=S;AC=1397  HG00117      1
# 94            94      MT  10398     A     G  VT=S;AC=1397  HG00120      1
# 97            97      MT  10398     A     G  VT=S;AC=1397  HG00121      1
# 104          104      MT  10398     A     G  VT=S;AC=1397  HG00124      1
# 163          163      MT  10398     A     G  VT=S;AC=1397  HG00154      1
# 184          184      MT  10398     A     G  VT=S;AC=1397  HG00177      1
# 203          203      MT  10398     A     G  VT=S;AC=1397  HG00185      1
# 232          232      MT  10398     A     G  VT=S;AC=1397  HG00235      1
# 271          271      MT  10398     A     G  VT=S;AC=1397  HG00253      1
# 290          290      MT  10398     A     G  VT=S;AC=1397  HG00258      1
# 304          304      MT  10398     A     G  VT=S;AC=1397  HG00261      1
# 346          346      MT  10398     A     G  VT=S;AC=1397  HG00276      1
# 386          386      MT  10398     A     G  VT=S;AC=1397  HG00315      1
# 406          406      MT  10398     A     G  VT=S;AC=1397  HG00326      1
# 415          415      MT  10398     A     G  VT=S;AC=1397  HG00329      1
# 421          421      MT  10398     A     G  VT=S;AC=1397  HG00331      1
# 428          428      MT  10398     A     G  VT=S;AC=1397  HG00332      1
# 433          433      MT  10398     A     G  VT=S;AC=1397  HG00334      1
# 450          450      MT  10398     A     G  VT=S;AC=1397  HG00338      1
# 472          472      MT  10398     A     G  VT=S;AC=1397  HG00346      1
# 476          476      MT  10398     A     G  VT=S;AC=1397  HG00349      1
# 488          488      MT  10398     A     G  VT=S;AC=1397  HG00355      1
# 517          517      MT  10398     A     G  VT=S;AC=1397  HG00369      1
# 528          528      MT  10398     A     G  VT=S;AC=1397  HG00375      1
# 547          547      MT  10398     A     G  VT=S;AC=1397  HG00403      1
# 554          554      MT  10398     A     G  VT=S;AC=1397  HG00404      1
# ...          ...     ...    ...   ...   ...           ...      ...    ...
# 4940        4940      MT  10398     A     G  VT=S;AC=1397  HG03397      1
# 4944        4944      MT  10398     A     G  VT=S;AC=1397  HG03401      1
# 4950        4950      MT  10398     A     G  VT=S;AC=1397  HG03410      1
# 4957        4957      MT  10398     A     G  VT=S;AC=1397  HG03419      1
# 4961        4961      MT  10398     A     G  VT=S;AC=1397  HG03428      1
# 4967        4967      MT  10398     A     G  VT=S;AC=1397  HG03432      1
# 4973        4973      MT  10398     A     G  VT=S;AC=1397  HG03433      1
# 4979        4979      MT  10398     A     G  VT=S;AC=1397  HG03437      1
# 4984        4984      MT  10398     A     G  VT=S;AC=1397  HG03439      1
# 4988        4988      MT  10398     A     G  VT=S;AC=1397  HG03445      1
# 4992        4992      MT  10398     A     G  VT=S;AC=1397  HG03446      1
# 4996        4996      MT  10398     A     G  VT=S;AC=1397  HG03449      1
# 5003        5003      MT  10398     A     G  VT=S;AC=1397  HG03451      1
# 5009        5009      MT  10398     A     G  VT=S;AC=1397  HG03452      1
# 5015        5015      MT  10398     A     G  VT=S;AC=1397  HG03455      1
# 5021        5021      MT  10398     A     G  VT=S;AC=1397  HG03457      1
# 5029        5029      MT  10398     A     G  VT=S;AC=1397  HG03458      1
# 5034        5034      MT  10398     A     G  VT=S;AC=1397  HG03460      1
# 5040        5040      MT  10398     A     G  VT=S;AC=1397  HG03461      1
# 5046        5046      MT  10398     A     G  VT=S;AC=1397  HG03464      1
# 5050        5050      MT  10398     A     G  VT=S;AC=1397  HG03472      1
# 5058        5058      MT  10398     A     G  VT=S;AC=1397  HG03473      1
# 5064        5064      MT  10398     A     G  VT=S;AC=1397  HG03476      1
# 5071        5071      MT  10398     A     G  VT=S;AC=1397  HG03478      1
# 5075        5075      MT  10398     A     G  VT=S;AC=1397  HG03479      1
# 5078        5078      MT  10398     A     G  VT=S;AC=1397  HG03484      1
# 5084        5084      MT  10398     A     G  VT=S;AC=1397  HG03485      1
# 5090        5090      MT  10398     A     G  VT=S;AC=1397  HG03488      1
# 5100        5100      MT  10398     A     G  VT=S;AC=1397  HG03499      1
# 5108        5108      MT  10398     A     G  VT=S;AC=1397  HG03511      1
#
#                 Mut CHROM_y    ...     Family ID Population  \
# 20    chrMT-10398-G      MT    ...       HG00101        GBR
# 27    chrMT-10398-G      MT    ...       HG00103        GBR
# 35    chrMT-10398-G      MT    ...       HG00106        GBR
# 44    chrMT-10398-G      MT    ...       HG00107        GBR
# 79    chrMT-10398-G      MT    ...       HG00117        GBR
# 94    chrMT-10398-G      MT    ...       HG00120        GBR
# 97    chrMT-10398-G      MT    ...       HG00121        GBR
# 104   chrMT-10398-G      MT    ...       HG00124        GBR
# 163   chrMT-10398-G      MT    ...       HG00154        GBR
# 184   chrMT-10398-G      MT    ...       HG00177        FIN
# 203   chrMT-10398-G      MT    ...       HG00185        FIN
# 232   chrMT-10398-G      MT    ...       HG00235        GBR
# 271   chrMT-10398-G      MT    ...       HG00253        GBR
# 290   chrMT-10398-G      MT    ...       HG00258        GBR
# 304   chrMT-10398-G      MT    ...       HG00261        GBR
# 346   chrMT-10398-G      MT    ...       HG00276        FIN
# 386   chrMT-10398-G      MT    ...       HG00315        FIN
# 406   chrMT-10398-G      MT    ...       HG00326        FIN
# 415   chrMT-10398-G      MT    ...       HG00329        FIN
# 421   chrMT-10398-G      MT    ...       HG00331        FIN
# 428   chrMT-10398-G      MT    ...       HG00332        FIN
# 433   chrMT-10398-G      MT    ...       HG00334        FIN
# 450   chrMT-10398-G      MT    ...       HG00338        FIN
# 472   chrMT-10398-G      MT    ...       HG00346        FIN
# 476   chrMT-10398-G      MT    ...       HG00349        FIN
# 488   chrMT-10398-G      MT    ...       HG00355        FIN
# 517   chrMT-10398-G      MT    ...       HG00369        FIN
# 528   chrMT-10398-G      MT    ...       HG00375        FIN
# 547   chrMT-10398-G      MT    ...         SH001        CHS
# 554   chrMT-10398-G      MT    ...         SH001        CHS
# ...             ...     ...    ...           ...        ...
# 4940  chrMT-10398-G      MT    ...       HG03397        MSL
# 4944  chrMT-10398-G      MT    ...          SL32        MSL
# 4950  chrMT-10398-G      MT    ...          SL35        MSL
# 4957  chrMT-10398-G      MT    ...          SL38        MSL
# 4961  chrMT-10398-G      MT    ...          SL42        MSL
# 4967  chrMT-10398-G      MT    ...       HG03432        MSL
# 4973  chrMT-10398-G      MT    ...       HG03433        MSL
# 4979  chrMT-10398-G      MT    ...       HG03437        MSL
# 4984  chrMT-10398-G      MT    ...          SL46        MSL
# 4988  chrMT-10398-G      MT    ...       HG03445        MSL
# 4992  chrMT-10398-G      MT    ...       HG03446        MSL
# 4996  chrMT-10398-G      MT    ...          SL49        MSL
# 5003  chrMT-10398-G      MT    ...          SL50        MSL
# 5009  chrMT-10398-G      MT    ...          SL50        MSL
# 5015  chrMT-10398-G      MT    ...          SL51        MSL
# 5021  chrMT-10398-G      MT    ...       HG03457        MSL
# 5029  chrMT-10398-G      MT    ...          SL52        MSL
# 5034  chrMT-10398-G      MT    ...       HG03460        MSL
# 5040  chrMT-10398-G      MT    ...       HG03461        MSL
# 5046  chrMT-10398-G      MT    ...          SL54        MSL
# 5050  chrMT-10398-G      MT    ...       HG03472        MSL
# 5058  chrMT-10398-G      MT    ...          SL57        MSL
# 5064  chrMT-10398-G      MT    ...          SL58        MSL
# 5071  chrMT-10398-G      MT    ...          SL59        MSL
# 5075  chrMT-10398-G      MT    ...          SL59        MSL
# 5078  chrMT-10398-G      MT    ...          SL61        MSL
# 5084  chrMT-10398-G      MT    ...          SL61        MSL
# 5090  chrMT-10398-G      MT    ...          PK42        PJL
# 5100  chrMT-10398-G      MT    ...         NG102        ESN
# 5108  chrMT-10398-G      MT    ...         NG106        ESN
#
#                Population Description  Gender  \
# 20    British in England and Scotland    male
# 27    British in England and Scotland    male
# 35    British in England and Scotland  female
# 44    British in England and Scotland    male
# 79    British in England and Scotland    male
# 94    British in England and Scotland  female
# 97    British in England and Scotland  female
# 104   British in England and Scotland  female
# 163   British in England and Scotland  female
# 184                Finnish in Finland  female
# 203                Finnish in Finland    male
# 232   British in England and Scotland  female
# 271   British in England and Scotland  female
# 290   British in England and Scotland  female
# 304   British in England and Scotland  female
# 346                Finnish in Finland  female
# 386                Finnish in Finland  female
# 406                Finnish in Finland  female
# 415                Finnish in Finland    male
# 421                Finnish in Finland  female
# 428                Finnish in Finland  female
# 433                Finnish in Finland  female
# 450                Finnish in Finland    male
# 472                Finnish in Finland  female
# 476                Finnish in Finland  female
# 488                Finnish in Finland  female
# 517                Finnish in Finland    male
# 528                Finnish in Finland    male
# 547       Southern Han Chinese, China    male
# 554       Southern Han Chinese, China  female
# ...                               ...     ...
# 4940            Mende in Sierra Leone    male
# 4944            Mende in Sierra Leone  female
# 4950            Mende in Sierra Leone  female
# 4957            Mende in Sierra Leone  female
# 4961            Mende in Sierra Leone  female
# 4967            Mende in Sierra Leone    male
# 4973            Mende in Sierra Leone    male
# 4979            Mende in Sierra Leone  female
# 4984            Mende in Sierra Leone    male
# 4988            Mende in Sierra Leone    male
# 4992            Mende in Sierra Leone  female
# 4996            Mende in Sierra Leone  female
# 5003            Mende in Sierra Leone    male
# 5009            Mende in Sierra Leone  female
# 5015            Mende in Sierra Leone  female
# 5021            Mende in Sierra Leone    male
# 5029            Mende in Sierra Leone  female
# 5034            Mende in Sierra Leone    male
# 5040            Mende in Sierra Leone  female
# 5046            Mende in Sierra Leone  female
# 5050            Mende in Sierra Leone    male
# 5058            Mende in Sierra Leone  female
# 5064            Mende in Sierra Leone  female
# 5071            Mende in Sierra Leone    male
# 5075            Mende in Sierra Leone  female
# 5078            Mende in Sierra Leone    male
# 5084            Mende in Sierra Leone  female
# 5090       Punjabi in Lahore,Pakistan  female
# 5100                  Esan in Nigeria  female
# 5108                  Esan in Nigeria  female
#
#                                         SnpDB    RSnum Clinical_Significance  \
# 20    http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 27    http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 35    http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 44    http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 79    http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 94    http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 97    http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 104   http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 163   http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 184   http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 203   http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 232   http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 271   http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 290   http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 304   http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 346   http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 386   http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 406   http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 415   http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 421   http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 428   http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 433   http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 450   http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 472   http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 476   http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 488   http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 517   http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 528   http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 547   http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 554   http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# ...                                       ...      ...                   ...
# 4940  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 4944  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 4950  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 4957  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 4961  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 4967  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 4973  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 4979  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 4984  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 4988  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 4992  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 4996  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 5003  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 5009  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 5015  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 5021  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 5029  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 5034  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 5040  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 5046  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 5050  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 5058  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 5064  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 5071  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 5075  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 5078  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 5084  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 5090  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 5100  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
# 5108  http://www.ncbi.nlm.nih.gov/snp/2853826  2853826                     0
#
#                                   Disease gene  Severity
# 20    Parkinson_disease\x2c_resistance_to  ND3         0
# 27    Parkinson_disease\x2c_resistance_to  ND3         0
# 35    Parkinson_disease\x2c_resistance_to  ND3         0
# 44    Parkinson_disease\x2c_resistance_to  ND3         0
# 79    Parkinson_disease\x2c_resistance_to  ND3         0
# 94    Parkinson_disease\x2c_resistance_to  ND3         0
# 97    Parkinson_disease\x2c_resistance_to  ND3         0
# 104   Parkinson_disease\x2c_resistance_to  ND3         0
# 163   Parkinson_disease\x2c_resistance_to  ND3         0
# 184   Parkinson_disease\x2c_resistance_to  ND3         0
# 203   Parkinson_disease\x2c_resistance_to  ND3         0
# 232   Parkinson_disease\x2c_resistance_to  ND3         0
# 271   Parkinson_disease\x2c_resistance_to  ND3         0
# 290   Parkinson_disease\x2c_resistance_to  ND3         0
# 304   Parkinson_disease\x2c_resistance_to  ND3         0
# 346   Parkinson_disease\x2c_resistance_to  ND3         0
# 386   Parkinson_disease\x2c_resistance_to  ND3         0
# 406   Parkinson_disease\x2c_resistance_to  ND3         0
# 415   Parkinson_disease\x2c_resistance_to  ND3         0
# 421   Parkinson_disease\x2c_resistance_to  ND3         0
# 428   Parkinson_disease\x2c_resistance_to  ND3         0
# 433   Parkinson_disease\x2c_resistance_to  ND3         0
# 450   Parkinson_disease\x2c_resistance_to  ND3         0
# 472   Parkinson_disease\x2c_resistance_to  ND3         0
# 476   Parkinson_disease\x2c_resistance_to  ND3         0
# 488   Parkinson_disease\x2c_resistance_to  ND3         0
# 517   Parkinson_disease\x2c_resistance_to  ND3         0
# 528   Parkinson_disease\x2c_resistance_to  ND3         0
# 547   Parkinson_disease\x2c_resistance_to  ND3         0
# 554   Parkinson_disease\x2c_resistance_to  ND3         0
# ...                                   ...  ...       ...
# 4940  Parkinson_disease\x2c_resistance_to  ND3         0
# 4944  Parkinson_disease\x2c_resistance_to  ND3         0
# 4950  Parkinson_disease\x2c_resistance_to  ND3         0
# 4957  Parkinson_disease\x2c_resistance_to  ND3         0
# 4961  Parkinson_disease\x2c_resistance_to  ND3         0
# 4967  Parkinson_disease\x2c_resistance_to  ND3         0
# 4973  Parkinson_disease\x2c_resistance_to  ND3         0
# 4979  Parkinson_disease\x2c_resistance_to  ND3         0
# 4984  Parkinson_disease\x2c_resistance_to  ND3         0
# 4988  Parkinson_disease\x2c_resistance_to  ND3         0
# 4992  Parkinson_disease\x2c_resistance_to  ND3         0
# 4996  Parkinson_disease\x2c_resistance_to  ND3         0
# 5003  Parkinson_disease\x2c_resistance_to  ND3         0
# 5009  Parkinson_disease\x2c_resistance_to  ND3         0
# 5015  Parkinson_disease\x2c_resistance_to  ND3         0
# 5021  Parkinson_disease\x2c_resistance_to  ND3         0
# 5029  Parkinson_disease\x2c_resistance_to  ND3         0
# 5034  Parkinson_disease\x2c_resistance_to  ND3         0
# 5040  Parkinson_disease\x2c_resistance_to  ND3         0
# 5046  Parkinson_disease\x2c_resistance_to  ND3         0
# 5050  Parkinson_disease\x2c_resistance_to  ND3         0
# 5058  Parkinson_disease\x2c_resistance_to  ND3         0
# 5064  Parkinson_disease\x2c_resistance_to  ND3         0
# 5071  Parkinson_disease\x2c_resistance_to  ND3         0
# 5075  Parkinson_disease\x2c_resistance_to  ND3         0
# 5078  Parkinson_disease\x2c_resistance_to  ND3         0
# 5084  Parkinson_disease\x2c_resistance_to  ND3         0
# 5090  Parkinson_disease\x2c_resistance_to  ND3         0
# 5100  Parkinson_disease\x2c_resistance_to  ND3         0
# 5108  Parkinson_disease\x2c_resistance_to  ND3         0
#
# [656 rows x 24 columns]
